# %% [markdown]
# # **Use YOLO : Object Detection !**

# %% [markdown]
# ## 0.미션

# %%
#########################################################
#                                                       #
#  폴더를 다 날리고 새롭게 시작하고 싶을 때,,, (!!취급주의!!)  #
#                                                       #
#########################################################

# import shutil
# import os

# # 삭제할 폴더 경로
# folder_path = '/content/my_face'

# # 폴더가 존재하면 삭제
# if os.path.exists(folder_path):
#     shutil.rmtree(folder_path)
#     print(f"{folder_path} 폴더가 삭제되었습니다.")
# else:
#     print(f"{folder_path} 폴더가 존재하지 않습니다.")

# %% [markdown]
# ### (1) 미션1
# 여러분은 노트북에서 얼굴 인식 파일을 실행시키기 위해 **문제에 적합한** UltraLytics YOLO 모델을 만들어야 합니다.
#
# 그 전에 가지고 있는 데이터셋을 **학습에 적합한 형태**로 바꿔야 합니다.
#
# - 1) 데이터셋을 불러옵니다.
#     - 주어진 데이터셋은 2가지입니다. 해당 데이터셋의 압축 파일을 해제해야 합니다.
#         1. [Face_Recognition_1](https://universe.roboflow.com/new-workspace-kuixc/face-recognition-dataset/dataset/1).zip
#         2. [Face_Recognition_2](https://universe.roboflow.com/td-vgaen/test-uiodm/dataset/2).zip
#         - 압축 파일을 로컬에 다운로드 받아서 **어떤 구조**인지 확인하세요.
#     - **여러분의 얼굴 이미지와 라벨링 작업까지 마친 파일 역시 데이터셋으로 압축하여 Google Colab에서 해제해주세요.**
# - 2) 데이터셋을 전처리합니다.
#     - UltraLytics YOLO 모델에서 요구하는 데이터셋 폴더의 구조가 있습니다.
#     - [UltraLytics YOLO 모델의 데이터셋 구조 링크](https://docs.ultralytics.com/datasets/detect/)
# - 3) YAML 파일을 생성합니다.
#     - 전처리까지 완료한 데이터셋의 구조를 YAML 파일에 저장합니다.

# %% [markdown]
# ### (2) 미션2
# 데이터셋의 폴더 구조를 **학습에 적합한 형태**로 만들었다면, **사전 학습된 UltraLytics YOLO 모델**에 Transfer Learning을 수행합니다.
#
# - 1) UltraLytics YOLO 모델 선택
#     - 세부 모델로 n, s, m, l, x가 있습니다. n가 가장 빠르고, x가 가장 연산량이 많습니다.
#     - [UltraLytics YOLO 모델 링크](https://docs.ultralytics.com/tasks/detect/)
# - 2) 선택한 UltraLytics YOLO 모델로 학습을 진행합니다.
#     - [UltraLytics YOLO 학습 명령어 링크](https://docs.ultralytics.com/modes/train/#train-settings)
# - 3) 학습이 완료되면 추론을 진행합니다.
#     - [UltraLytics YOLO 추론 명령어 링크](https://docs.ultralytics.com/modes/predict/#inference-arguments)
# - 4) 해당 UltraLytics YOLO 모델을 **반드시** 저장합니다.
#     - 모델을 **반드시** 저장하세요.
#     - .pt 형태로 Colab에 저장이 될 것입니다. 해당 파일을 **로컬에 다운로드** 하세요.

# %% [markdown]
# ## 1.환경설정

# %% [markdown]
# * 세부 요구사항
#     - 경로 설정 : 구글콜랩
#         * 구글 드라이브 바로 밑에 project4 폴더를 만드세요.
#         * 데이터 파일을 복사해 넣습니다.
#         * 필요하다고 판단되는 라이브러리를 추가하세요.

# %% [markdown]
# ### (1) 경로 설정

# %% [markdown]
# * 구글 드라이브 연결

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/project4'

# %% [markdown]
# ### (2) 라이브러리 설치 및 불러오기

# %% [markdown]
# * 라이브러리 로딩

# %%
# Colab에서 UTF-8 로케일을 강제로 설정
#!export LC_ALL=C.UTF-8
#!export LANG=C.UTF-8

# %%
## colab에서 세션 재시작을 요구하는 팝업이 뜨면 재시작 누르세요.
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 879.0/879.0 kB 37.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## 2.미션1

# %% [markdown]
# 여러분은 노트북에서 얼굴 인식 파일을 실행시키기 위해 **문제에 적합한** UltraLytics YOLO 모델을 만들어야 합니다.
#
# 그 전에 가지고 있는 데이터셋을 **학습에 적합한 형태**로 바꿔야 합니다.
#
# - 1) 데이터셋을 불러옵니다.
#     - 주어진 데이터셋은 2가지입니다. 해당 데이터셋의 압축 파일을 해제해야 합니다.
#         1. [Face_Recognition_1](https://universe.roboflow.com/new-workspace-kuixc/face-recognition-dataset/dataset/1).zip
#         2. [Face_Recognition_2](https://universe.roboflow.com/td-vgaen/test-uiodm/dataset/2).zip
#         - 압축 파일을 로컬에 다운로드 받아서 **어떤 구조**인지 확인하세요.
#     - **여러분의 얼굴 이미지와 라벨링 작업까지 마친 파일 역시 데이터셋으로 압축하여 Google Colab에서 해제해주세요.**
# - 2) 데이터셋을 전처리합니다.
#     - UltraLytics YOLO 모델에서 요구하는 데이터셋 폴더의 구조가 있습니다.
#     - [UltraLytics YOLO 모델의 데이터셋 구조 링크](https://docs.ultralytics.com/datasets/detect/)
# - 3) YAML 파일을 생성합니다.
#     - 전처리까지 완료한 데이터셋의 구조를 YAML 파일에 저장합니다.

# %% [markdown]
# ### (1) 데이터셋 불러오기

# %% [markdown]
# * **세부 요구사항**
#     - 데이터셋을 불러옵니다.
#         - 주어진 데이터셋은 2가지입니다. 해당 데이터셋의 압축 파일을 해제해야 합니다.
#             1. [Face_Recognition_1](https://universe.roboflow.com/new-workspace-kuixc/face-recognition-dataset/dataset/1).zip
#             2. [Face_Recognition_2](https://universe.roboflow.com/td-vgaen/test-uiodm/dataset/2).zip
#             - 압축 파일을 로컬에 다운로드 받아서 **어떤 구조**인지 확인하세요.
#         - **여러분의 얼굴 이미지와 라벨링 작업까지 마친 파일 역시 데이터셋으로 압축하여 Google Colab에서 해제해주세요.**
#     - 데이터셋 압축 파일을 가급적 **Colab에 폴더를 생성한 후 해제**하세요.
#     - 예시 코드에서 사용한 라이브러리
#         - os, zipfile

# %%
import os
import zipfile

# %% [markdown]
# #### 1) 데이터셋 불러오기

# %%
# 내 얼굴

# %%
data_jyFace = path + '/jy_2.zip'
data_jyFace
# Out:
# '/content/drive/MyDrive/project4/jy_2.zip'

# %%
## Colab에 생성할 본인 얼굴 폴더 경로
extract_folder = '/content/jy_face'

if not os.path.exists(extract_folder):
    os.makedirs(extract_folder)

with zipfile.ZipFile(data_jyFace, 'r') as zip_ref:
    for f in zip_ref.namelist():
        if not f.endswith('/') and f.lower().endswith(('.jpg', 'txt', 'yaml')):
            file_name = os.path.basename(f)

            if not file_name.startswith('._'):
                # 압축 파일 내 원래 경로 유지
                full_path = os.path.join(extract_folder, f)
                os.makedirs(os.path.dirname(full_path), exist_ok=True)

                with zip_ref.open(f) as source, open(full_path, 'wb') as target:
                    target.write(source.read())

# %%
data_hjFace = path + '/hj.zip'
data_hjFace
# Out:
# '/content/drive/MyDrive/project4/hj.zip'

# %%
## Colab에 생성할 본인 얼굴 폴더 경로
extract_folder = '/content/hj_face'

if not os.path.exists(extract_folder):
    os.makedirs(extract_folder)

with zipfile.ZipFile(data_hjFace, 'r') as zip_ref:
    for f in zip_ref.namelist():
        if not f.endswith('/') and f.lower().endswith(('.jpg', 'txt', 'yaml')):
            file_name = os.path.basename(f)

            if not file_name.startswith('._'):
                # 압축 파일 내 원래 경로 유지
                full_path = os.path.join(extract_folder, f)
                os.makedirs(os.path.dirname(full_path), exist_ok=True)

                with zip_ref.open(f) as source, open(full_path, 'wb') as target:
                    target.write(source.read())

# %%
# 기본 경로 설정
datasets_path = '/content/Datasets'
train_images_path = os.path.join(datasets_path, 'train', 'images')
train_labels_path = os.path.join(datasets_path, 'train', 'labels')
val_images_path = os.path.join(datasets_path, 'valid', 'images')
val_labels_path = os.path.join(datasets_path, 'valid', 'labels')

# 폴더 생성
os.makedirs(train_images_path, exist_ok=True)
os.makedirs(train_labels_path, exist_ok=True)
os.makedirs(val_images_path, exist_ok=True)
os.makedirs(val_labels_path, exist_ok=True)

# 원본 폴더 경로들
source_folders = {
    'jy_face': {'images': '/content/jy_face/images', 'labels': '/content/jy_face/labels'},
    'hj_face': {'images': '/content/hj_face/images', 'labels': '/content/hj_face/labels'},
    'other_face': {'images': '/content/other_face/images', 'labels': '/content/other_face/labels'}
}

# %%
# 경로 설정
folders = ['train', 'valid']
jpg_counts = {}
total_jpg_count = 0

# .jpg 파일 개수 세기
for folder in folders:
    # images 폴더의 경로
    images_path = os.path.join(extract_folder, folder, 'images')

    # .jpg 파일 개수
    jpg_count = len([f for f in os.listdir(images_path) if f.lower().endswith('.jpg')])
    jpg_counts[folder] = jpg_count

    # 총합에 추가
    total_jpg_count += jpg_count

# 비율 계산
jpg_ratios = {folder: (count / total_jpg_count * 100) for folder, count in jpg_counts.items()}

# 결과 출력
jpg_counts, total_jpg_count, jpg_ratios
# Out:
# ({'train': 480, 'valid': 40},
#  520,
#  {'train': 92.3076923076923, 'valid': 7.6923076923076925})

# %%
# 다른 얼굴

# %%
data_other1 = path + '/Face_Recognition_1.zip'
data_other1
# Out:
# '/content/drive/MyDrive/project4/Face_Recognition_1.zip'

# %%
## Colab에 생성할 다른 얼굴 폴더 경로
extract_folder = '/content/other_face1'

if not os.path.exists(extract_folder):
    os.makedirs(extract_folder)

with zipfile.ZipFile(data_other1, 'r') as zip_ref:
    for f in zip_ref.namelist():
        if not f.endswith('/') and f.lower().endswith(('.jpg', 'txt', 'yaml')):
            file_name = os.path.basename(f)

            if not file_name.startswith('._'):
                # 압축 파일 내 원래 경로 유지
                full_path = os.path.join(extract_folder, f)
                os.makedirs(os.path.dirname(full_path), exist_ok=True)

                with zip_ref.open(f) as source, open(full_path, 'wb') as target:
                    target.write(source.read())

# %%
# 경로 설정
folders = ['train', 'valid']
jpg_counts = {}
total_jpg_count = 0

# .jpg 파일 개수 세기
for folder in folders:
    # images 폴더의 경로
    images_path = os.path.join(extract_folder, folder, 'images')

    # .jpg 파일 개수
    jpg_count = len([f for f in os.listdir(images_path) if f.lower().endswith('.jpg')])
    jpg_counts[folder] = jpg_count

    # 총합에 추가
    total_jpg_count += jpg_count

# 비율 계산
jpg_ratios = {folder: (count / total_jpg_count * 100) for folder, count in jpg_counts.items()}

# 결과 출력
jpg_counts, total_jpg_count, jpg_ratios
# Out:
# ({'train': 5214, 'valid': 509},
#  5723,
#  {'train': 91.10606325353835, 'valid': 8.893936746461646})

# %%
data_other2 = path + '/Face_Recognition_2.zip'
data_other2
# Out:
# '/content/drive/MyDrive/project4/Face_Recognition_2.zip'

# %%
## Colab에 생성할 다른 얼굴 폴더 경로
extract_folder = '/content/other_face2'

if not os.path.exists(extract_folder):
    os.makedirs(extract_folder)

with zipfile.ZipFile(data_other2, 'r') as zip_ref:
    for f in zip_ref.namelist():
        if not f.endswith('/') and f.lower().endswith(('.jpg', 'txt', 'yaml')):
            file_name = os.path.basename(f)

            if not file_name.startswith('._'):
                # 압축 파일 내 원래 경로 유지
                full_path = os.path.join(extract_folder, f)
                os.makedirs(os.path.dirname(full_path), exist_ok=True)

                with zip_ref.open(f) as source, open(full_path, 'wb') as target:
                    target.write(source.read())

# %%
# 경로 설정
folders = ['train', 'valid']
jpg_counts = {}
total_jpg_count = 0

# .jpg 파일 개수 세기
for folder in folders:
    # images 폴더의 경로
    images_path = os.path.join(extract_folder, folder, 'images')

    # .jpg 파일 개수
    jpg_count = len([f for f in os.listdir(images_path) if f.lower().endswith('.jpg')])
    jpg_counts[folder] = jpg_count

    # 총합에 추가
    total_jpg_count += jpg_count

# 비율 계산
jpg_ratios = {folder: (count / total_jpg_count * 100) for folder, count in jpg_counts.items()}

# 결과 출력
jpg_counts, total_jpg_count, jpg_ratios
# Out:
# ({'train': 3489, 'valid': 997},
#  4486,
#  {'train': 77.7753009362461, 'valid': 22.2246990637539})

# %% [markdown]
# ### (2) 데이터셋 전처리

# %% [markdown]
# * **세부 요구사항**
#     - Label 파일, 즉 txt 파일의 클래스를 수정하셔야 합니다.
#         - 여러 클래스로 구분되어 있는 것을 하나로 통일해주세요.
#         - 이것은 **다른 사람의 얼굴**에 대해 전처리하는 작업입니다.
#     - UltraLytics YOLO 모델에서 요구하는 데이터셋 폴더의 구조가 있습니다.
#     - [UltraLytics YOLO 모델의 데이터셋 구조 링크](https://docs.ultralytics.com/datasets/detect/)
#     - 예시 코드에서 사용한 라이브러리
#         - os, glob, random, shutil, numpy

# %%
import glob
import random
import shutil
import numpy as np

# %%
data_jy_face = '/content/jy_face'
data_hj_face = '/content/hj_face'
data_other_face1 = '/content/other_face_1'
data_other_face2 = '/content/other_face_2'

# %%
from collections import defaultdict

# 폴더 경로 설정
folders = ['train', 'valid']
class_count_dict = defaultdict(int)

for folder in folders:
    labels_folder = os.path.join('/content/jy_face', folder, 'labels')

    # labels 폴더 내의 모든 .txt 파일 읽기
    for label_file in os.listdir(labels_folder):
        if label_file.lower().endswith('.txt'):
            with open(os.path.join(labels_folder, label_file), 'r') as f:
                # 각 .txt 파일의 내용을 읽고 클래스 추가
                for line in f:
                    # 라인에서 클래스 정보 추출 (예: 첫 번째 열)
                    class_id = line.split()[0]  # 필요에 따라 조정 가능
                    class_count_dict[class_id] += 1

# 고유 클래스 목록과 개수
class_list = list(class_count_dict.keys())
total_classes = len(class_list)

# 결과 출력
class_count_list = {class_id: count for class_id, count in class_count_dict.items()}

print('클래스 목록 :', class_list)
print('클래스 총 개수 :', total_classes)
print('클래스별 개수\n', class_count_list)
# Out:
# 클래스 목록 : ['0']
# 클래스 총 개수 : 1
# 클래스별 개수
#  {'0': 438}

# %%
from collections import defaultdict

# 폴더 경로 설정
folders = ['train', 'valid']
class_count_dict = defaultdict(int)

for folder in folders:
    labels_folder = os.path.join('/content/hj_face', folder, 'labels')

    # labels 폴더 내의 모든 .txt 파일 읽기
    for label_file in os.listdir(labels_folder):
        if label_file.lower().endswith('.txt'):
            with open(os.path.join(labels_folder, label_file), 'r') as f:
                # 각 .txt 파일의 내용을 읽고 클래스 추가
                for line in f:
                    # 라인에서 클래스 정보 추출 (예: 첫 번째 열)
                    class_id = line.split()[0]  # 필요에 따라 조정 가능
                    class_count_dict[class_id] += 1

# 고유 클래스 목록과 개수
class_list = list(class_count_dict.keys())
total_classes = len(class_list)

# 결과 출력
class_count_list = {class_id: count for class_id, count in class_count_dict.items()}

print('클래스 목록 :', class_list)
print('클래스 총 개수 :', total_classes)
print('클래스별 개수\n', class_count_list)
# Out:
# 클래스 목록 : ['0']
# 클래스 총 개수 : 1
# 클래스별 개수
#  {'0': 520}

# %%
from collections import defaultdict

# 폴더 경로 설정
folders = ['train','valid']
class_count_dict = defaultdict(int)

for folder in folders:
    labels_folder = os.path.join('/content/other_face1', folder, 'labels')

    # labels 폴더 내의 모든 .txt 파일 읽기
    for label_file in os.listdir(labels_folder):
        if label_file.lower().endswith('.txt'):
            with open(os.path.join(labels_folder, label_file), 'r') as f:
                # 각 .txt 파일의 내용을 읽고 클래스 추가
                for line in f:
                    # 라인에서 클래스 정보 추출 (예: 첫 번째 열)
                    class_id = line.split()[0]  # 필요에 따라 조정 가능
                    class_count_dict[class_id] += 1

# 고유 클래스 목록과 개수
class_list = list(class_count_dict.keys())
total_classes = len(class_list)

# 결과 출력
class_count_list = {class_id: count for class_id, count in class_count_dict.items()}

print('클래스 목록 :', class_list)
print('클래스 총 개수 :', total_classes)
print('클래스별 개수\n', class_count_list)
# Out:
# 클래스 목록 : ['10', '2', '7', '12', '11', '1', '3', '8', '0', '5', '4', '9', '6']
# 클래스 총 개수 : 13
# 클래스별 개수
#  {'10': 1288, '2': 1271, '7': 1914, '12': 1236, '11': 981, '1': 878, '3': 1766, '8': 1158, '0': 1207, '5': 1900, '4': 1587, '9': 1227, '6': 1770}

# %%
from collections import defaultdict

# 폴더 경로 설정
folders = ['train', 'valid']
class_count_dict = defaultdict(int)

for folder in folders:
    labels_folder = os.path.join('/content/other_face2', folder, 'labels')

    # labels 폴더 내의 모든 .txt 파일 읽기
    for label_file in os.listdir(labels_folder):
        if label_file.lower().endswith('.txt'):
            with open(os.path.join(labels_folder, label_file), 'r') as f:
                # 각 .txt 파일의 내용을 읽고 클래스 추가
                for line in f:
                    # 라인에서 클래스 정보 추출 (예: 첫 번째 열)
                    class_id = line.split()[0]  # 필요에 따라 조정 가능
                    class_count_dict[class_id] += 1

# 고유 클래스 목록과 개수
class_list = list(class_count_dict.keys())
total_classes = len(class_list)

# 결과 출력
class_count_list = {class_id: count for class_id, count in class_count_dict.items()}

print('클래스 목록 :', class_list)
print('클래스 총 개수 :', total_classes)
print('클래스별 개수\n', class_count_list)
# Out:
# 클래스 목록 : ['0', '1']
# 클래스 총 개수 : 2
# 클래스별 개수
#  {'0': 4191, '1': 2504}

# %% [markdown]
# #### 1) Label 파일의 클래스 값 변경

# %%
# jy: 1
# 폴더 경로 설정
folders = ['train', 'valid']

for folder in folders:
    labels_folder = os.path.join('/content/jy_face', folder, 'labels')

    # labels 폴더 내의 모든 .txt 파일 읽기
    for label_file in os.listdir(labels_folder):
        if label_file.lower().endswith('.txt'):
            label_path = os.path.join(labels_folder, label_file)
            with open(label_path, 'r') as f:
                lines = f.readlines()

            # 각 클래스 ID를 1로 변경 후 파일 업데이트
            with open(label_path, 'w') as f:
                for line in lines:
                    # 첫 번째 항목을 1로 대체
                    parts = line.split()
                    parts[0] = '1'
                    new_line = ' '.join(parts) + '\n'
                    f.write(new_line)

# %%
# hj: 2
# 폴더 경로 설정
folders = ['train', 'valid']

for folder in folders:
    labels_folder = os.path.join('/content/hj_face', folder, 'labels')

    # labels 폴더 내의 모든 .txt 파일 읽기
    for label_file in os.listdir(labels_folder):
        if label_file.lower().endswith('.txt'):
            label_path = os.path.join(labels_folder, label_file)
            with open(label_path, 'r') as f:
                lines = f.readlines()

            # 각 클래스 ID를 2로 변경 후 파일 업데이트
            with open(label_path, 'w') as f:
                for line in lines:
                    # 첫 번째 항목을 2로 대체
                    parts = line.split()
                    parts[0] = '2'
                    new_line = ' '.join(parts) + '\n'
                    f.write(new_line)

# %%
# 폴더 경로 설정
folders = ['train', 'valid']

for folder in folders:
    labels_folder = os.path.join('/content/other_face1', folder, 'labels')

    # labels 폴더 내의 모든 .txt 파일 읽기
    for label_file in os.listdir(labels_folder):
        if label_file.lower().endswith('.txt'):
            label_path = os.path.join(labels_folder, label_file)
            with open(label_path, 'r') as f:
                lines = f.readlines()

            # 각 클래스 ID를 0으로 변경 후 파일 업데이트
            with open(label_path, 'w') as f:
                for line in lines:
                    # 첫 번째 항목을 0으로 대체
                    parts = line.split()
                    parts[0] = '0'
                    new_line = ' '.join(parts) + '\n'
                    f.write(new_line)

# %%
# 폴더 경로 설정
folders = ['train', 'valid']

for folder in folders:
    labels_folder = os.path.join('/content/other_face2', folder, 'labels')

    # labels 폴더 내의 모든 .txt 파일 읽기
    for label_file in os.listdir(labels_folder):
        if label_file.lower().endswith('.txt'):
            label_path = os.path.join(labels_folder, label_file)
            with open(label_path, 'r') as f:
                lines = f.readlines()

            # 각 클래스 ID를 0으로 변경 후 파일 업데이트
            with open(label_path, 'w') as f:
                for line in lines:
                    # 첫 번째 항목을 0으로 대체
                    parts = line.split()
                    parts[0] = '0'
                    new_line = ' '.join(parts) + '\n'
                    f.write(new_line)

# %% [markdown]
# #### 2) 모델이 요하는 구조의 폴더 생성

# %%
data_face = '/content/face'
data_face_train = data_face + '/train'
data_face_test = data_face + '/test'
data_face_val = data_face + '/valid'
data_f_train_image = data_face_train + '/images'
data_f_train_labels = data_face_train + '/labels'
data_f_test_image = data_face_test + '/images'
data_f_test_labels = data_face_test + '/labels'
data_f_val_image = data_face_val + '/images'
data_f_val_labels = data_face_val + '/labels'

# %% [markdown]
# #### 3) 각 폴더에 데이터 옮기기

# %%
import os
import shutil

# 원본 폴더들
source_folders = ['jy_face', 'hj_face', 'other_face1', 'other_face2']

# 통합 대상 경로
data_face = '/content/face'
data_face_train = os.path.join(data_face, 'train')
#data_face_test = os.path.join(data_face, 'test')
data_face_val = os.path.join(data_face, 'valid')

# 각 폴더 내의 images와 labels 경로
data_folders = {
    'train': {'images': os.path.join(data_face_train, 'images'), 'labels': os.path.join(data_face_train, 'labels')},
    #'test': {'images': os.path.join(data_face_test, 'images'), 'labels': os.path.join(data_face_test, 'labels')},
    'valid': {'images': os.path.join(data_face_val, 'images'), 'labels': os.path.join(data_face_val, 'labels')}
}

# 통합 폴더 생성
for folder in data_folders.values():
    os.makedirs(folder['images'], exist_ok=True)
    os.makedirs(folder['labels'], exist_ok=True)

# 파일 옮기기
for source in source_folders:
    for split in ['train', 'valid']:
        source_images = os.path.join(source, split, 'images')
        source_labels = os.path.join(source, split, 'labels')

        if os.path.exists(source_images):
            for image_file in os.listdir(source_images):
                shutil.copy(os.path.join(source_images, image_file), data_folders[split]['images'])

        if os.path.exists(source_labels):
            for label_file in os.listdir(source_labels):
                shutil.copy(os.path.join(source_labels, label_file), data_folders[split]['labels'])

print("파일 복사 완료")
# Out:
# 파일 복사 완료

# %%
# 경로 설정
folders = ['train', 'valid']
jpg_counts = {}
total_jpg_count = 0

# .jpg 파일 개수 세기
for folder in folders:
    # images 폴더의 경로
    images_path = os.path.join('/content/face', folder, 'images')

    # .jpg 파일 개수
    jpg_count = len([f for f in os.listdir(images_path) if f.lower().endswith('.jpg')])
    jpg_counts[folder] = jpg_count

    # 총합에 추가
    total_jpg_count += jpg_count

# 결과 출력
jpg_counts, total_jpg_count
# Out:
# ({'train': 9588, 'valid': 1582}, 11170)

# %% [markdown]
# ### (3) YAML 파일 생성

# %% [markdown]
# * **세부 요구사항**
#     - 데이터셋의 구조를 YAML 파일에 작성하여 저장합니다.
#     - 예시 코드에서 사용한 라이브러리
#         - yaml(pyyaml)

# %% [markdown]
# #### 1) 데이터셋 구조 코드 작성

# %% [markdown]
# #### 2) YAML 파일 작성

# %%
import yaml

# %%
with open('/content/face/data.yaml', 'w') as f:
    yaml.dump(dataset_info, f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-f1f41cee417f> in <cell line: 1>()
#       1 with open('/content/face/data.yaml', 'w') as f:
# ----> 2     yaml.dump(dataset_info, f)
#
# NameError: name 'dataset_info' is not defined

# %%
# YAML

yaml_content = """
train: /content/face/train/images
val: /content/face/valid/images
names:
  0: other_face
  1: jy_face
  2: hj_face
"""

# %% [markdown]
# ## 3.미션2

# %% [markdown]
# 데이터셋의 폴더 구조를 **학습에 적합한 형태**로 만들었다면, **사전 학습된 UltraLytics YOLO 모델**에 Transfer Learning을 수행합니다.
#
# - 1) UltraLytics YOLO 모델 선택
#     - 세부 모델로 n, s, m, l, x가 있습니다. n가 가장 빠르고, x가 가장 연산량이 많습니다.
#     - [UltraLytics YOLO 모델 링크](https://docs.ultralytics.com/tasks/detect/)
# - 2) 선택한 UltraLytics YOLO 모델로 학습을 진행합니다.
#     - [UltraLytics YOLO 학습 명령어 링크](https://docs.ultralytics.com/modes/train/#train-settings)
# - 3) 학습이 완료되면 추론을 진행합니다.
#     - [UltraLytics YOLO 추론 명령어 링크](https://docs.ultralytics.com/modes/predict/#inference-arguments)
# - 4) 해당 UltraLytics YOLO 모델을 **반드시** 저장합니다.
#     - 모델을 **반드시** 저장하세요.
#     - .pt 형태로 Colab에 저장이 될 것입니다. 해당 파일을 **로컬에 다운로드** 하세요.

# %% [markdown]
# #### (1) UltraLytics YOLO 모델 선택

# %% [markdown]
# * **세부 요구사항**
#     - 세부 모델로 n, s, m, l, x가 있습니다. n가 가장 빠르고, x가 가장 연산량이 많습니다.
#     - [UltraLytics YOLO 모델 링크](https://docs.ultralytics.com/tasks/detect/)

# %%
from ultralytics import YOLO, settings
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
import os
os.environ['WANDB_MODE'] = 'disabled'

# %%
model = YOLO(model='yolo11s.pt', task='detect')
# Out:
# ...
# 100%|██████████| 18.4M/18.4M [00:00<00:00, 307MB/s]

# %% [markdown]
# #### (2) UltraLytics YOLO 모델 학습

# %% [markdown]
# * **세부 요구사항**
#     - 선택한 UltraLytics YOLO 모델로 학습을 진행합니다.
#     - [UltraLytics YOLO 학습 명령어 링크](https://docs.ultralytics.com/modes/train/#train-settings)

# %%
import os
import glob

image_folder = '/content/face/train/images'
my_images = glob.glob(os.path.join(image_folder, '*.jpg'))
print(f'내 사진 개수: {len(my_images)}')
# Out:
# 내 사진 개수: 9588

# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.2

# %%
import subprocess
subprocess.check_call(['pip', 'install', '--upgrade', 'torch', 'ultralytics'])
# Out:
# 0

# %%
results_train = model.train(model='/content/yolo11s.pt',
                            data='/content/face/data.yaml',
                            epochs=10,
                            patience=3,
                            )
# Out:
# Ultralytics 8.3.27 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
print('Classes: ', model.names)
# Out:
# Classes:  {0: 'other_face', 1: 'jy_face', 2: 'hj_face'}

# %% [markdown]
# #### (3) UltraLytics YOLO 추론

# %% [markdown]
# * **세부 요구사항**
#     - 학습이 완료되면 추론을 진행합니다.
#     - [UltraLytics YOLO 추론 명령어 링크](https://docs.ultralytics.com/modes/predict/)

# %%
results = model.predict()
# Out:
# WARNING ⚠️ 'source' is missing. Using 'source=/usr/local/lib/python3.10/dist-packages/ultralytics/assets'.
#
# image 1/2 /usr/local/lib/python3.10/dist-packages/ultralytics/assets/bus.jpg: 640x480 5 other_faces, 63.3ms
# image 2/2 /usr/local/lib/python3.10/dist-packages/ultralytics/assets/zidane.jpg: 384x640 3 other_faces, 60.6ms
# Speed: 2.1ms preprocess, 61.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)

# %% [markdown]
# #### (4) UltraLytics YOLO 모델 저장

# %% [markdown]
# * **세부 요구사항**
#     - 모델을 **반드시** 저장하세요.
#     - .pt 형태로 Colab에 저장이 될 것입니다. 해당 파일을 **로컬에 다운로드** 하세요.

# %%
model.save('/content/drive/MyDrive/project4/best_please_2.pt')
